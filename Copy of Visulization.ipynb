# %% [markdown]
# Lets assume dataset with rows and col
#
# Area: 600 800 1000 1500 2000
# Price:4    6    9    14   22
#
# -independent values will be plotted on x axis
# -dependant values will be plotted on y axis
#
# Types of ploats
# 1)Scatter plot
# --It shows the relationship b/w 2 variables
# --the  data gets expressed as collection of points
#
#
# 2)Line plot--
#
# --Line plot are drawn by joining staright lines coonecting data points x and y axis intersects
#
# 3)Bar Chart--
# vertical and horizontal Bars
# It shows data comparision  changes over a perod represented in another axis
#
# 4)Pie chart--
# circular graph
# data represented different componnants
# represent data the percentage
#
# 5) Histogram--
# It is used when data remains distributed
# It same like bar chart
#
# 6)Boxplot--
# used to get the outliers
#
# 7) HeatMap--
# graphical representation of data
# in the format of matrix with differnt color

# %% [markdown]
# Seborn---
# used for visulization
# Quality of graph is much better in seaborn as compare to matploatlib
# --used to create 3D images

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#reading the dataframe
car=pd.read_csv('cars .csv')
car.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
car.shape   #205 rows   15 col
# Out:
# (205, 15)

# %%
car.info()

# %%
car.tail()  #returns last 5 rows

# %%
car.describe()

# %%
car['width'].mean()
# Out:
# 65.90780487804878

# %%
car['price'].min()
# Out:
# 5118

# %%
car['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
car['fuel-type'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
car['fuel-type'].value_counts()['gas']
# Out:
# 185

# %%
car['width'].max()
# Out:
# 72.3

# %%
car.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
#Scatter plot
plt.figure(figsize=(5,5))
plt.title("Width v/s price of car")
x=car['width']
y=car['price']
plt.scatter(x,y)
plt.xlabel('width of car')
plt.ylabel('price of car')
plt.show()

# %%
#Histogram
plt.hist(car['fuel-type'])
plt.xlabel('Fuel Type')
plt.ylabel('No of cars')
plt.title("Fuel type vs no of cars")
c=car['fuel-type'].value_counts()

plt.show()

# %%
#Bar plot

car['fuel-type'].value_counts().plot(kind='bar')
plt.xlabel('Fuel Type')
plt.ylabel('No of cars')
plt.title("Fuel type vs no of cars")
c=car['fuel-type'].value_counts()
plt.show()

# %%
#pie plot
car['body-style'].value_counts().plot(kind='pie',autopct='%.2f%%',explode=(0,0.3,0,0.5,0))
plt.show()

# %%
#Countplot
plt.figure(figsize=(5,5))
sns.countplot(data=car,x='body-style')
f=car['body-style'].value_counts()
plt.yticks(f)
plt.show()

# %%
#heatmap
sns.heatmap(car.corr(),annot=True)
plt.show()

# %%
#Boxplot
X=car.iloc[:,:-1] #retrive all col but  except price
#X=car['syboling','city-mpg','highway-mpg'......]
target=car.iloc[:,-1]  #price
#target=car['price']
sns.boxplot(data=X,x=target,y='make')
plt.grid()
